# %% [raw]
# ---
# description: The database keeps track of all files, processing steps, and settings
# output-file: database.html
# title: database
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Database)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/database.py#L19){target="_blank" style="float:right; font-size:smaller"}
#
# ### Database
#
# >      Database (project_configs:findmycells.configs.ProjectConfigs)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(FileHistory)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/database.py#L322){target="_blank" style="float:right; font-size:smaller"}
#
# ### FileHistory
#
# >      FileHistory (file_id:str, source_image_filepath:pathlib.PosixPath)
#
# Initialize self.  See help(type(self)) for accurate signature.
