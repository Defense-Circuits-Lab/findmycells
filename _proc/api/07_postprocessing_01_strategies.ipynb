# %% [raw]
# ---
# description: Defines all options you can use for postprocessing of your segmentation
#   data (findmycells.postprocessing.strategies)
# order: 8
# output-file: postprocessing_01_strategies.html
# title: postprocessing options
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(ReconstructCellsIn3DFrom2DInstanceLabelsStrat)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/postprocessing/strategies.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### ReconstructCellsIn3DFrom2DInstanceLabelsStrat
#
# >      ReconstructCellsIn3DFrom2DInstanceLabelsStrat ()
#
# Description;
# Include requirements
# Mention multi matches traceback which can be used in inspection

# %%
#| echo: false
#| output: asis
show_doc(FillHolesStrat)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/postprocessing/strategies.py#L338){target="_blank" style="float:right; font-size:smaller"}
#
# ### FillHolesStrat
#
# >      FillHolesStrat ()
#
# Specific conditions can lead to "holes" within the segmentations of your image features.
# This can make total sense, for instance if you`re analyzing specifically the cells cytoplasm,
# and want to spare out the nucleus, or if you`re analyzing ring-like features.
# In other cases, however, these "holes" may be artefacts and require correction.
# This strategy was designed for exactly this purpose: fill the "holes" in
# your segmented features, if they should not be there.

# %%
#| echo: false
#| output: asis
show_doc(ApplyExclusionCriteriaStrat)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/postprocessing/strategies.py#L405){target="_blank" style="float:right; font-size:smaller"}
#
# ### ApplyExclusionCriteriaStrat
#
# >      ApplyExclusionCriteriaStrat ()
#
# Another typical postprocessing step is to filter your data by applying exclusion
# criteria. Please check the following list of exclusion criteria with detailed
# descriptions to see which criteria are currently implemented in your installed
# findmycells version. Importantly, if you would like to use this strategy, please
# make sure to run this strategy as the *last* postprocessing strategy, to ensure that
# all other processing steps have been completed.
#
#     - Minimum feature position relative to area ROI:
#         If you provided ROIs that denote in which area of each image you'd like to
#         quantify the image features, you can use this criterion to specify when to
# ...
