# %% [raw]
# ---
# description: Defines several general purpose functions that are used throughout *findmycells*
#   (findmycells.utils)
# order: 18
# output-file: utils.html
# title: utility functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(list_dir_no_hidden)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/utils.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### list_dir_no_hidden
#
# >      list_dir_no_hidden (path:pathlib.PosixPath,
# >                          only_dirs:Optional[bool]=False,
# >                          only_files:Optional[bool]=False)

# %%
#| echo: false
#| output: asis
show_doc(load_zstack_as_array_from_single_planes)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/utils.py#L32){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_zstack_as_array_from_single_planes
#
# >      load_zstack_as_array_from_single_planes (path:pathlib.PosixPath,
# >                                               file_id:str,
# >                                               minx:Optional[int]=None,
# >                                               maxx:Optional[int]=None,
# >                                               miny:Optional[int]=None,
# >                                               maxy:Optional[int]=None)

# %%
#| echo: false
#| output: asis
show_doc(unpad_x_y_dims_in_3d_array)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/utils.py#L54){target="_blank" style="float:right; font-size:smaller"}
#
# ### unpad_x_y_dims_in_3d_array
#
# >      unpad_x_y_dims_in_3d_array (padded_3d_array:numpy.ndarray, pad_width:int)

# %%
#| echo: false
#| output: asis
show_doc(get_polygon_from_instance_segmentation)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/utils.py#L58){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_polygon_from_instance_segmentation
#
# >      get_polygon_from_instance_segmentation (single_plane:numpy.ndarray,
# >                                              label_id:int)

# %%
#| echo: false
#| output: asis
show_doc(download_sample_data)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/utils.py#L69){target="_blank" style="float:right; font-size:smaller"}
#
# ### download_sample_data
#
# >      download_sample_data (destination_dir_path:pathlib.PosixPath)
#
# Test data for findmycells can be found here: https://zenodo.org/record/7655292#.Y_LI1R-ZNhE
# DOI: 10.5281/zenodo.7655292
