# %% [raw]
# ---
# description: Extends the classes defined in core for the segmentation-specific requirements
#   (findmycells.segmentation.specs)
# order: 16
# output-file: segmentation_00_specs.html
# title: segmentation subclasses
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(SegmentationStrategy)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/segmentation/specs.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### SegmentationStrategy
#
# >      SegmentationStrategy ()
#
# Extending the `ProcssingStrategy` base class for segmentation as processing subtype.
# Also adding another property that denotes the type of segmentation (i.e. instance or semantic).

# %%
#| echo: false
#| output: asis
show_doc(SegmentationObject)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/segmentation/specs.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### SegmentationObject
#
# >      SegmentationObject ()
#
# Extending the `ProcessingObject` base class for segmentation as processing subtype.
# The clear_all_tmp_data() method allows to clear all chached results that might
# accumulate for instance while using deepflash2.
