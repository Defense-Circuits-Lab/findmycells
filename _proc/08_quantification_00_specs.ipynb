# %% [raw]
# ---
# description: This module defines the specifications of quantification related subclasses
#   of `ProcessingStrategy` and `ProcessingObject`
# output-file: quantification_00_specs.html
# title: Specifications of quantification specific subclasses
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(QuantificationStrategy)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/quantification/specs.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### QuantificationStrategy
#
# >      QuantificationStrategy ()
#
# Note for developers: When implementing a new quantification strategy, remember to add
# the following line at the end of the ".run()" method, to ensure that the quantification
# results are added to the database:
#
# quantification_object = self._add_quantification_results_to_database(quantification_object = quantification_object,
# results = quantification_results)

# %%
#| echo: false
#| output: asis
show_doc(QuantificationObject)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/quantification/specs.py#L40){target="_blank" style="float:right; font-size:smaller"}
#
# ### QuantificationObject
#
# >      QuantificationObject ()
#
# Extending the `ProcessingObject` base class for quantification as processing subtype.
