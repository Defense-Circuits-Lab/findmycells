# %% [raw]
# ---
# description: This module implements the postprocessing-related subclasses of `ProcessingStrategy`
#   and `ProcessingObject`
# order: 5
# output-file: postprocessing_00_specs.html
# title: postprocessing related subclasses
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(PostprocessingStrategy)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/postprocessing/specs.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### PostprocessingStrategy
#
# >      PostprocessingStrategy ()
#
# Extending the `ProcssingStrategy` base class for postprocessing as processing subtype.

# %%
#| echo: false
#| output: asis
show_doc(PostprocessingObject)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/postprocessing/specs.py#L27){target="_blank" style="float:right; font-size:smaller"}
#
# ### PostprocessingObject
#
# >      PostprocessingObject ()
#
# Extending the `ProcessingObject` base class for postprocessing as processing subtype.
