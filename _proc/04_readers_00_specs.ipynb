# %% [raw]
# ---
# description: 'This module specifies the default values of the available data readers,
#   their descriptions, and their widgets:'
# output-file: readers_00_specs.html
# title: Specification of default values of available data readers
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(ReaderSpecsABC)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/readers/specs.py#L14){target="_blank" style="float:right; font-size:smaller"}
#
# ### ReaderSpecsABC
#
# >      ReaderSpecsABC ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#| echo: false
#| output: asis
show_doc(MicroscopyReaderSpecs)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/readers/specs.py#L78){target="_blank" style="float:right; font-size:smaller"}
#
# ### MicroscopyReaderSpecs
#
# >      MicroscopyReaderSpecs ()
#
# Helper class that provides a standard way to create an ABC using
# inheritance.

# %%
#| echo: false
#| output: asis
show_doc(ROIReaderSpecs)
# Out:
# ---
#
# [source](https://github.com/Defense-Circuits-Lab/findmycells/blob/main/findmycells/readers/specs.py#L160){target="_blank" style="float:right; font-size:smaller"}
#
# ### ROIReaderSpecs
#
# >      ROIReaderSpecs ()
#
# findmycells enables analyses of multiple ROIs in the image data. To do so, they will be matched based on their ID that will
# be retrieved from the ROI file. Some softwares that create these ROI-files, however, create default IDs for the individual
# ROIs that will interfere with this matching. For instance, in Fiji / ImageJ2, created ROIs get its centroid (?) pixel
# coordinates as default ID (e.g. something like "523-378"). Since such default IDs most likely won´t be consistent throughout
# your entire image dataset, findmycells provides you with two options to adress this:
# a) You can set 'load_roi_ids_from_file' to False (default):
#   This will cause findmycells to ignore the IDs of the ROIs that are saved in the provided ROI file and assign them with
# ...
