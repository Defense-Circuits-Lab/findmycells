# %% [raw]
# ---
# description: The database holds all the relevant metadata information related to the
#   *findmycells* project and is used to keep track of the progress
# output-file: database.html
# title: database
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(listdir_nohidden)
# Out:
# ---
#
# ### listdir_nohidden
#
# >      listdir_nohidden (path:pathlib.Path)

# %%
#|output: asis
#| echo: false
show_doc(Database)
# Out:
# ---
#
# ### Database
#
# >      Database (user_input_via_gui:dict)
#
# The database object is intended to collect and hold all information about
# the image analysis project at hand. Depending on the type of analysis that
# shall be performed, the Database needs to be flexible and adopt to the
# respective needs. For instance, there might be more than just two groups
# that are investigated, or just a single group but with multiple images per
# subject, and so on.
